# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.preprocessing import MinMaxScaler
plt.style.use('ggplot')

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense, Dropout

# %%
df = pd.read_csv(r'/Users/suraj/OneDrive/Documents/csProjects/stockPrices/BTC-USD.csv')
df.tail()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-5d49464f1cca> in <module>
# ----> 1 df = pd.read_csv(r'C:\Users\danie\Desktop\original.csv')
#       2 df.tail()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1166     def _make_engine(self, engine="c"):
#    1167         if engine == "c":
# -> 1168             self._engine = CParserWrapper(self.f, **self.options)
#    1169         else:
#    1170             if engine == "python":
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1996         kwds["usecols"] = self.usecols
#    1997
# -> 1998         self._reader = parsers.TextReader(src, **kwds)
#    1999         self.unnamed_cols = self._reader.unnamed_cols
#    2000
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\danie\\Desktop\\original.csv'

# %%
df = df.set_index("Date")[['Close']].tail(1000)
df = df.set_index(pd.to_datetime(df.index))

df.head()
print('done')
# Out:
# done

# %%
scaler = MinMaxScaler()
df = pd.DataFrame(scaler.fit_transform(df), columns =df.columns, index=df.index)
df.head()
# Out:
#                Close
# Date
# 2016-07-25  0.007485
# 2016-07-26  0.007493
# 2016-07-27  0.007471
# 2016-07-28  0.007540
# 2016-07-29  0.007504

# %%
print('done')
df.plot(figsize=(14,8))
plt.title('btc prices')
plt.ylabel('normalized prices')
plt.show()
# Out:
# done

# %%
def split_sequences(seq, n_steps_in, n_steps_out):
    X,y =[], []
    
    for i in range(len(seq)):
        end = i+n_steps_in
        out_end = end+ n_steps_out
        
        if out_end >len(seq):
            break
            
        seq_x, seq_y = seq[i:end], seq[end:out_end]
        
        X.append(seq_x)
        y.append(seq_y)
    
    return np.array(X), np.array(y)

# %%
def visualize_results(results):
    history = results.history
    plt.figure(figsize=(12,4))
    plt.plot(history['val_loss'])
    plt.plot(history['loss'])
    plt.legend(['val_loss','loss'])
    plt.title('Loss')
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.show()
    
    plt.figure(figsize=(12,4))
    plt.plot(history['val_accuracy'])
    plt.plot(history['accuracy'])
    plt.legend(['val_accuracy','accuracy'])
    plt.title('Accuracy')
    plt.xlabel('epochs')
    plt.ylabel('accuracy')
    plt.show()

# %%
n_per_in = 30
n_per_out = 10

n_features = 1

X,y = split_sequences(list(df.Close), n_per_in,n_per_out)

print(X.shape)

X = X.reshape(X.shape[0],X.shape[1],n_features)

print(X.shape)
print(y.shape)
# Out:
# (961, 30)
# (961, 30, 1)
# (961, 10)

# %%
model = Sequential()
model.add(LSTM(30, activation='softsign', return_sequences=True, input_shape=(n_per_in,n_features)))
model.add(LSTM(10, activation='softsign', return_sequences=True))
model.add(LSTM(10, activation='softsign', return_sequences=True))
model.add(LSTM(10, activation='softsign', return_sequences=True))
model.add(LSTM(10, activation='softsign', return_sequences=True))
model.add(LSTM(10, activation='softsign'))
model.add(Dense(n_per_out))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# unified_lstm (UnifiedLSTM)   (None, 30, 30)            3840
# _________________________________________________________________
# unified_lstm_1 (UnifiedLSTM) (None, 30, 10)            1640
# _________________________________________________________________
# unified_lstm_2 (UnifiedLSTM) (None, 30, 10)            840
# _________________________________________________________________
# unified_lstm_3 (UnifiedLSTM) (None, 30, 10)            840
# _________________________________________________________________
# unified_lstm_4 (UnifiedLSTM) (None, 30, 10)            840
# _________________________________________________________________
# unified_lstm_5 (UnifiedLSTM) (None, 10)                840
# _________________________________________________________________
# dense (Dense)                (None, 10)                110
# =================================================================
# Total params: 8,950
# Trainable params: 8,950
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='mse', metrics=['accuracy'])

# %%
res = model.fit(X,y, epochs=50, batch_size=32, validation_split=0.1)
# Out:
# Train on 864 samples, validate on 97 samples
# Epoch 1/50
# 864/864 [==============================] - 8s 9ms/sample - loss: 0.0787 - accuracy: 0.0764 - val_loss: 0.0099 - val_accuracy: 0.0619
# Epoch 2/50
# 864/864 [==============================] - 2s 3ms/sample - loss: 0.0522 - accuracy: 0.0752 - val_loss: 0.0046 - val_accuracy: 0.0619
# Epoch 3/50
# 864/864 [==============================] - 3s 3ms/sample - loss: 0.0279 - accuracy: 0.1019 - val_loss: 0.0036 - val_accuracy: 0.1443
# Epoch 4/50
# 864/864 [==============================] - 3s 3ms/sample - loss: 0.
50
# 864/864 [==============================] - 2s 3ms/sample - loss: 0.0027 - accuracy: 0.1794 - val_loss: 6.4845e-04 - val_accuracy: 0.2268
# Epoch 37/50
# 864/864 [==============================] - 2s 3ms/sample - loss: 0.0026 - accuracy: 0.1505 - val_loss: 5.5304e-04 - val_accuracy: 0.2165
# Epoch 38/50
# 864/864 [==============================] - 3s 3ms/sample - loss: 0.0024 - accuracy: 0.1887 - val_loss: 5.6832e-04 - val_accuracy: 0.1649
# Epoch 39/50
# 864/864 [==============================] - 3s 3ms/sample - loss: 0.0029 - accuracy: 0.1898 - val_loss: 5.9831e-04 - val_accuracy: 0.2268
# Epoch 40/50
# 864/864 [==============================] - 3s 3ms/sample - loss: 0.0029 - accuracy: 0.1169 - val_loss: 7.1172e-04 - val_accuracy: 0.1237
# Epoch 41/50
# 864/864 [==============================] - 3s 3ms/sample - loss: 0.0024 - accuracy: 0.1435 - val_loss: 9.1289e-04 - val_accuracy: 0.1031
# Epoch 42/50
# 864/864 [==============================] - 3s 3ms/sample - loss: 0.0024 - accuracy: 0.1898 - val_loss: 5.4178e-04 - val_accuracy: 0.1649
# Epoch 43/50
# 864/864 [==============================] - 3s 3ms/sample - loss: 0.0024 - accuracy: 0.1644 - val_loss: 7.7105e-04 - val_accuracy: 0.1546
# Epoch 44/50
# 864/864 [==============================] - 3s 3ms/sample - loss: 0.0024 - accuracy: 0.1875 - val_loss: 0.0011 - val_accuracy: 0.1649
# Epoch 45/50
# 864/864 [==============================] - 3s 3ms/sample - loss: 0.0023 - accuracy: 0.1725 - val_loss: 5.3097e-04 - val_accuracy: 0.1753
# Epoch 46/50
# 864/864 [==============================] - 3s 3ms/sample - loss: 0.0022 - accuracy: 0.1979 - val_loss: 6.1906e-04 - val_accuracy: 0.1753
# Epoch 47/50
# 864/864 [==============================] - 3s 3ms/sample - loss: 0.0022 - accuracy: 0.1644 - val_loss: 5.3027e-04 - val_accuracy: 0.1649
# Epoch 48/50
# 864/864 [==============================] - 3s 3ms/sample - loss: 0.0023 - accuracy: 0.1794 - val_loss: 5.5634e-04 - val_accuracy: 0.1649
# Epoch 49/50
# 864/864 [==============================] - 3s 3ms/sample - loss: 0.0026 - accuracy: 0.1829 - val_loss: 5.5205e-04 - val_accuracy: 0.1753
# Epoch 50/50
# 864/864 [==============================] - 3s 3ms/sample - loss: 0.0022 - accuracy: 0.1227 - val_loss: 6.9417e-04 - val_accuracy: 0.1649

# %%
visualize_results(res)

# %%
plt.figure(figsize=(12,4))

yhat = model.predict(X[-1].reshape(1,n_per_in,n_features)).tolist()[0]

yhat = scaler.inverse_transform(np.array(yhat).reshape(-1,1)).tolist()

actual = scaler.inverse_transform(y[-1].reshape(-1,1))

print("predicted ", yhat)
plt.plot(yhat, label='predicted')

print("actuals ", actual.tolist())
plt.plot(actual.tolist(), label='actual')

plt.title("Predicted vs Actual")
plt.ylabel('price')
plt.legend()
plt.show()
# Out:
# predicted  [[4912.262064297145], [4989.79725017942], [4918.667767113412], [5202.870563605651], [5073.596425997504], [5173.468368035614], [5109.717495818642], [5310.222981394987], [5257.663498060285], [5360.748534120661]]
# actuals  [[5081.5], [5080.660156], [5165.589844], [5037.27002], [5212.810059], [5236.259765999999], [5289.750000000001], [5295.529785], [5326.180176], [5305.740234]]

# %%
yhat = model.predict(np.array(df.tail(n_per_in)).reshape(1,n_per_in,n_features)).tolist()[0]
yhat = scaler.inverse_transform(np.array(yhat).reshape(-1,1)).tolist()

preds = pd.DataFrame(yhat, index=pd.date_range(start=df.index[-1], periods=len(yhat),freq="D"), columns=df.columns)

print(preds)

periods = 10

actual = pd.DataFrame(scaler.inverse_transform(df[['Close']].tail(periods)), index = df.Close.tail(periods).index, columns = df.columns).append(preds.head(1))

plt.figure(figsize=(12,4))
plt.plot(actual, label='actuals')
plt.plot(preds, label='predictions')
plt.ylabel("price")
plt.ylabel('dates')
plt.title(f'forecasting the next {len(yhat)} days')
plt.legend()
plt.show()
# Out:
#                   Close
# 2019-04-20  5776.016102
# 2019-04-21  5796.570362
# 2019-04-22  5676.378196
# 2019-04-23  5953.560172
# 2019-04-24  5813.209419
# 2019-04-25  5967.600130
# 2019-04-26  5816.551598
# 2019-04-27  6047.160828
# 2019-04-28  6075.158803
# 2019-04-29  6113.264695
